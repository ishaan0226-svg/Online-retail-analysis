# %%
import pandas as pd

df = pd.read_excel("../data/raw/Online Retail.xlsx")
df.head()
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
pip install pandas openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --------- ------------------------------ 2.4/9.9 MB 19.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 21.4 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 18.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 17.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ------------- -------------------------- 4.2/12.5 MB 22.1 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.5 MB 21.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 21.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...
